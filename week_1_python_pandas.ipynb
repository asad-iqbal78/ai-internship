# %% [markdown]
# <a href="https://colab.research.google.com/github/asad-iqbal78/ai-internship/blob/main/week_1_python_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, Asad")
name = "Asad"
age = 15
age = age + 1
print(name)
print(age)

fruits = ["apple", "bnana", "graphes"]
print(fruits)
print(fruits[0])
print(fruits[2])

fruits.append("orange")
print(fruits)

person = {
    "name" : "Asad",
    "age" : 23,
    "city" : "Chakwal"
}
print(person)

if age >= 18:
  print("Adult")
else:
  print("Under 18")

for fruit in fruits:
  print(fruit)

number = [10, 20, 30, 40, 50]
for n in number:
  if n > 20:
   print(n)
def greet(name):
  print("hello " + name)
greet("Iqbal")

num = [1,2,3,4,5]
square=[]
for n in num:
  square.append(n*n)
print(square)
double=[n*2 for n in num]
print(double)
# Out:
# hello, Asad
# Asad
# 16
# ['apple', 'bnana', 'graphes']
# apple
# graphes
# ['apple', 'bnana', 'graphes', 'orange']
# {'name': 'Asad', 'age': 23, 'city': 'Chakwal'}
# Under 18
# apple
# bnana
# graphes
# orange
# 30
# 40
# 50
# hello Iqbal
# [1, 4, 9, 16, 25]
# [2, 4, 6, 8, 10]

# %%
#import Numpy
import numpy as np
num = np.array([10,20,30,40])
print(num)
print(num.mean())
print(num.max())
print(num.min())
print(num.sum())

print(num*2)
# Out:
# [10 20 30 40]
# 25.0
# 40
# 10
# 100
# [20 40 60 80]

# %%
#imports Pandas
import pandas as pd
data = {
    "name":["Asad", "Ali", "Haider"],
    "age" : [20, 21, 22],
    "score": [70, 80, 90]
}
df = pd.DataFrame(data)
print(df)
df.head()
df.columns
df["name"]
print(df["name"])
# Out:
#      name  age  score
# 0    Asad   20     70
# 1     Ali   21     80
# 2  Haider   22     90
# 0      Asad
# 1       Ali
# 2    Haider
# Name: name, dtype: object

# %%
#create CSV
import pandas as pd
student = {
    "name":["asad","ali","haider"],
    "age":[17,18,19],
    "score":[70,80,90]
}
df = pd.DataFrame(data)
df.to_csv("student.csv", index=False)
print("CSV created!")
# Out:
# CSV created!

# %%
#load CSV
df = pd.read_csv("student.csv")
print(df)
# Out:
#      name  age  score
# 0    Asad   20     70
# 1     Ali   21     80
# 2  Haider   22     90
